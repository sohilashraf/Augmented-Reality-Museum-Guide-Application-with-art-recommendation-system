# %%
import pandas as pd
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity
import pickle as pkl
import numpy as np

# %%
df = pd.read_excel("data set - New.xlsx")
df = df[['exhibits', 'Text in English', 'Category', 'Time Period']].dropna().reset_index(drop=True)

df['cleaned_exhibit'] = df['exhibits'].astype(str).str.strip().str.lower()
df
# Out:
#                                         exhibits  \
# 0                             the_female_peasent
# 1                            Statue_ofthe_sphinx
# 2                                   Hassan_Fathi
# 3                                  Royal_Statues
# 4                                  Greek_Statues
# 5                                         Khonsu
# 6                                    Ra_Horakhty
# 7                                       Senenmut
# 8                          Box_ofthe_Holy Qur’an
# 9                                  The_HolyQuran
# 10                             King_Thutmose_III
# 11                                  King_Fouad_I
# 12                               theVizier_Paser
# 13                Sphinxof_theking_Amenemhat_III
# 14                        Amun_Ra_Kingof_TheGods
# 15                        Nazlet_Khater_Skeleton
# 16               Pen_Menkh_TheGovernerOf_Dendara
# 17                         TheCoffinOf_Lady_Isis
# 18                           CoffinOf_Nedjemankh
# 19                         TheCoffinOf_Sennedjem
# 20                                        A_silo
# 21                           Captives_statuettes
# 22       Chair_from_the tomb_of_Queen_Hetepheres
# 23                                          Maat
# 24                          Mahalawi_water_ewers
# 25                                  Mamluk_Lamps
# 26                                Khedive_Ismail
# 27                  Mohamed_Talaat_Pasha_Harb_00
# 28                             Model_of_building
# 29                            Muhammad_Ali_Pasha
# 30  Puplit _of_the_Mosque_of_Abu_Bakr_bin_Mazhar
# 31                      The_Preist_Psamtik_seneb
# 32      The_Madrasaa_and_Mosque_of_Sultan_Hassan
# 33                             Wekalet_al-Ghouri
# 34                             The_birth_of_Isis
# 35                                king_Akhenaten
# 36              The_Kiswa_Covering_of_holy_Kaaba
# 37              AQueen_in_the_form_of_the_Sphinx
# 38                       Purification_with_water
# 39                                    Mashrabiya
# 40                                     Astrolabe
# 41                                         Baker
# 42                      The_Protective_Goddesses
# 43                                        Miller
# 44                             Hapi_the_Scribe\n
# 45                                         Thoth
# 46                      Ottoman_Period_Carpet \n
# 47                            Stela_of_King_Qa'a
# 48                          Zaynab_Khatun_house
# 49                                     God_Nilus
#
#                                       Text in English       Category  \
# 0   The Femal Peasent: This statue is considered o...         Statue
# 1   Statue of the Sphinx: \nStatue of Sphinx, whic...         Statue
# 2   Hassan Fathi (1900-1989):  Hassan Fathi was bo...  Architecture
# 3   Royal Statues: When the Ptolemaic state was es...         Statue
# 4   Greek Statues: The art of ancient Greece had a...         Statue
# 5   Khonsu: Khonsu was the god of the moon and a m...         Statue
# 6   Ra-Horakhty: Ra-Horakhty represented a doctrin...         Statue
# 7   Senenmut : Senenmut served as a close advisor ...         Statue
# 8   Box of the Holy Qur'an: This huge box was made...       Artifact
# 9   The Holy Quran: Finely calligraphed and bound ...       Artifact
# 10  King Thutmose III : Thutmose ill was one of th...         Statue
# 11  King Fouad I ( 1868-1936 ): The son of Khedive...         Statue
# 12  The vizier Paser:  Paser lived during the reig...         Statue
# 13  Sphinxof_theking_Amenemhat_III:  The statues o...         Statue
# 14  Amon-Ra : the king of the gods. Amun-Ra was th...         Statue
# 15  Nazlet Khater Skeleton :  This skeleton was fo...       Artifact
# 16  Pen Menkh TheGovernerOf Dendara : he Greco-Rom...         Statue
# 17  The Coffin of Lady Isis : This coffin was disc...         Statue
# 18  Coffin of Nedjemankh :  Nedjemankh was a pries...         Statue
# 19  The coffin of Sennedjem :  The inner coffin of...         Statue
# 20  A Silo: Silos were used to store grains, mainl...       Artifact
# 21  Captive's statuettes: The figures of captives ...         Statue
# 22  Chair from the tomb of Queen Hetepheres: old k...       Artifact
# 23  Maat: Maat was the daughter of the sun God Atu...         Statue
# 24   "Mahallawi" Water Ewers: A group of "Mahallaw...       Artifact
# 25  Mamluk Lamps : A group of glass lamps decorate...       Artifact
# 26  Khedive Ismail(1830-1895): during the reign of...         Statue
# 27  Mohamed Talaat Pasha Harb: (1867- 1941) A lead...         Statue
# 28  Model of Building: This model shows an apartme...  Architecture
# 29  Muhammad Ali Pasha: (1769 -1849) He was born i...         Statue
# 30  Pulpit of Mosque of Abu Bakr bin Mazhar: Abu B...  Architecture
# 31  The Priest Psamtik Seneb : The Naophorous or N...         Statue
# 32  The Madrasa and Mosque of Sultan Hassan:  The ...  Architecture
# 33  Wekalet al-Ghouri is the remaining part of the...  Architecture
# 34  The birth of isis: The unique plaque was found...         Statue
# 35  king Akhenaten: When Amenhotep IV becomes a ph...         Statue
# 36  The "Kiswa" Covering of the Holy Kaaba: Manufa...       Artifact
# 37  A Queen in the form of the Sphinx: This statue...         Statue
# 38  Purification with water: Upon his arrival from...         Statue
# 39  Mashrabiya "Oriel Window" : \n"The Organizatio...  Architecture
# 40  Astrolabe :   The Astrolabe was invented by th...       Artifact
# 41  Baker :\nBread was an essential part of the di...         Statue
# 42  The Protective Goddesses :     A group of stat...         Statue
# 43  Miller :     It is a unique statue depicting a...         Statue
# 44  Hapi the Scribe :\nScribes were amongst the hi...         Statue
# 45  Thoth :\nThe ancient Egyptians sanctified the ...         Statue
# 46  Ottoman Period Carpet :\nA ground carpet predo...       Artifact
# 47  Stela of King Qa'a :\nQa'a was the lastking of...         Statue
# 48  Zaynab Khatun house :\nThis house originally b...  Architecture
# 49  God Nilus : The god Nilus was a symbol of the ...         Statue
#
#            Time Period                               cleaned_exhibit
# 0         Modern Egypt                            the_female_peasent
# 1          Old Kingdom                           statue_ofthe_sphinx
# 2         Modern Egypt                                  hassan_fathi
# 3            Ptolemaic                                 royal_statues
# 4          Hellenistic                                 greek_statues
# 5          New Kingdom                                        khonsu
# 6          New Kingdom                                   ra_horakhty
# 7          New Kingdom                                      senenmut
# 8               Mamluk                         box_ofthe_holy qur’an
# 9         Modern Egypt                                 the_holyquran
# 10         New Kingdom                             king_thutmose_iii
# 11        Modern Egypt                                  king_fouad_i
# 12         New Kingdom                               thevizier_paser
# 13      Middle Kingdom                sphinxof_theking_amenemhat_iii
# 14         New Kingdom                        amun_ra_kingof_thegods
# 15  Ancient Egyptian\t                        nazlet_khater_skeleton
# 16           Ptolemaic               pen_menkh_thegovernerof_dendara
# 17         New Kingdom                         thecoffinof_lady_isis
# 18           Ptolemaic                           coffinof_nedjemankh
# 19         New Kingdom                         thecoffinof_sennedjem
# 20  Ancient Egyptian\t                                        a_silo
# 21         New Kingdom                           captives_statuettes
# 22         Old Kingdom       chair_from_the tomb_of_queen_hetepheres
# 23         New Kingdom                                          maat
# 24      Islamic Period                          mahalawi_water_ewers
# 25              Mamluk                                  mamluk_lamps
# 26        Modern Egypt                                khedive_ismail
# 27        Modern Egypt                  mohamed_talaat_pasha_harb_00
# 28         Greco-Roman                             model_of_building
# 29        Modern Egypt                            muhammad_ali_pasha
# 30              Mamluk  puplit _of_the_mosque_of_abu_bakr_bin_mazhar
# 31  Ancient Egyptian\t                      the_preist_psamtik_seneb
# 32              Mamluk      the_madrasaa_and_mosque_of_sultan_hassan
# 33              Mamluk                             wekalet_al-ghouri
# 34           Ptolemaic                             the_birth_of_isis
# 35         New Kingdom                                king_akhenaten
# 36        Modern Egypt              the_kiswa_covering_of_holy_kaaba
# 37         Old Kingdom              aqueen_in_the_form_of_the_sphinx
# 38         New Kingdom                       purification_with_water
# 39      Islamic Period                                    mashrabiya
# 40      Islamic Period                                     astrolabe
# 41         Old Kingdom                                         baker
# 42         New Kingdom                      the_protective_goddesses
# 43         Old Kingdom                                        miller
# 44         New Kingdom                               hapi_the_scribe
# 45         Greco-Roman                                         thoth
# 46        Modern Egypt                         ottoman_period_carpet
# 47         Old Kingdom                            stela_of_king_qa'a
# 48              Mamluk                           zaynab_khatun_house
# 49         Greco-Roman                                     god_nilus

# %%
texts = df['Text in English'].astype(str).tolist()
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = TFBertModel.from_pretrained('bert-base-uncased')

tokens = tokenizer(
    texts,
    padding='max_length',
    truncation=True,
    max_length=128,
    return_tensors="tf"
)

#outputs = model(**tokens)
outputs = model(input_ids=tokens['input_ids'], attention_mask=tokens['attention_mask'])
cls_embeddings = outputs.last_hidden_state[:, 0, :]
text_embeddings = cls_embeddings.numpy()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
encoder = OneHotEncoder(sparse_output=False)
category_encoded = encoder.fit_transform(df[['Category']])
time_period_encoded = encoder.fit_transform(df[['Time Period']])

# %%
with open("all_image_features1.pkl", "rb") as f:
    train_data_dict = pkl.load(f)

# %%
image_features = []
exhibit_names_from_df = df['exhibits'].tolist()

for name in exhibit_names_from_df:
    if name in train_data_dict and len(train_data_dict[name]) > 0:
        vectors = [entry['feature'] for entry in train_data_dict[name]]
        avg_vector = np.mean(np.stack(vectors), axis=0)
    else:
        avg_vector = np.zeros(2048)
    image_features.append(avg_vector)

image_features = np.array(image_features)

# Safe normalization
norms = np.linalg.norm(image_features, axis=1, keepdims=True)
norms[norms == 0] = 1
image_features = image_features / norms

# %%
# 6. Combine All Features

combined_features = np.concatenate([
    text_embeddings ,
    category_encoded ,
    time_period_encoded,
    image_features
], axis=1)

# %%
similarity_matrix = cosine_similarity(combined_features)

# %%
def recommend(
    exhibit_name, top_k=5,
    filter_category=None,
    filter_time_period=None
):
    cleaned_exhibit = exhibit_name.strip().lower()

    if cleaned_exhibit not in df['cleaned_exhibit'].values:
        print(f"❌ Exhibit '{exhibit_name}' not found.")
        suggestions = df['exhibits'][df['cleaned_exhibit'].str.contains(cleaned_exhibit[:3])]
        if not suggestions.empty:
            print("🔍 Did you mean:", ", ".join(suggestions.values))
        return pd.DataFrame()

    exhibit_index = df[df['cleaned_exhibit'] == cleaned_exhibit].index[0]

    similarity_scores = list(enumerate(similarity_matrix[exhibit_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    top_indices = similarity_scores[1:]  # skip self

    recommendations = []
    for i, score in top_indices:
        exhibit = df.loc[i]
        category = exhibit['Category'].strip()
        time_period = exhibit['Time Period'].strip()

        if filter_category and category != filter_category:
            continue
        if filter_time_period and time_period != filter_time_period:
            continue

        recommendations.append({
            "Index": i,
            "Exhibit": exhibit['exhibits'],
            "Category": category,
            "Time Period": time_period,
            "Similarity Score": round(score, 4)
        })

        if len(recommendations) >= top_k:
            break

    recommendations_df = pd.DataFrame(recommendations)
    print(f"\n📍 Top {top_k} Recommendations for: {df.loc[exhibit_index, 'exhibits']} (Index: {exhibit_index})")
    return recommendations_df

# %%
recommend("Hassan_Fathi", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: Hassan_Fathi (Index: 2)
#    Index                                       Exhibit      Category  \
# 0     27                  Mohamed_Talaat_Pasha_Harb_00        Statue
# 1      0                            the_female_peasent        Statue
# 2     48                          Zaynab_Khatun_house   Architecture
# 3     30  Puplit _of_the_Mosque_of_Abu_Bakr_bin_Mazhar  Architecture
# 4      8                         Box_ofthe_Holy Qur’an      Artifact
#
#     Time Period  Similarity Score
# 0  Modern Egypt            0.8407
# 1  Modern Egypt            0.8216
# 2        Mamluk            0.8184
# 3        Mamluk            0.8064
# 4        Mamluk            0.7959

# %%
recommend("the_female_peasent", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: the_female_peasent (Index: 0)
#    Index                           Exhibit  Category  Time Period  \
# 0     37  AQueen_in_the_form_of_the_Sphinx    Statue  Old Kingdom
# 1     16   Pen_Menkh_TheGovernerOf_Dendara    Statue    Ptolemaic
# 2     25                      Mamluk_Lamps  Artifact       Mamluk
# 3     17             TheCoffinOf_Lady_Isis    Statue  New Kingdom
# 4     18               CoffinOf_Nedjemankh    Statue    Ptolemaic
#
#    Similarity Score
# 0            0.8618
# 1            0.8591
# 2            0.8575
# 3            0.8517
# 4            0.8472

# %%
recommend("King_Fouad_I", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: King_Fouad_I (Index: 11)
#    Index                       Exhibit      Category   Time Period  \
# 0     29            Muhammad_Ali_Pasha        Statue  Modern Egypt
# 1     27  Mohamed_Talaat_Pasha_Harb_00        Statue  Modern Egypt
# 2     26                Khedive_Ismail        Statue  Modern Egypt
# 3     12               theVizier_Paser        Statue   New Kingdom
# 4      2                  Hassan_Fathi  Architecture  Modern Egypt
#
#    Similarity Score
# 0            0.8582
# 1            0.8024
# 2            0.7819
# 3            0.7807
# 4            0.7671

# %%
recommend("King_Thutmose_III", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: King_Thutmose_III (Index: 10)
#    Index                Exhibit Category  Time Period  Similarity Score
# 0      7               Senenmut   Statue  New Kingdom            0.9109
# 1     41                  Baker   Statue  Old Kingdom            0.8965
# 2     47     Stela_of_King_Qa'a   Statue  Old Kingdom            0.8944
# 3     44      Hapi_the_Scribe\n   Statue  New Kingdom            0.8923
# 4     17  TheCoffinOf_Lady_Isis   Statue  New Kingdom            0.8922

# %%
recommend("Khedive_Ismail", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: Khedive_Ismail (Index: 26)
#    Index                       Exhibit Category   Time Period  \
# 0     27  Mohamed_Talaat_Pasha_Harb_00   Statue  Modern Egypt
# 1     29            Muhammad_Ali_Pasha   Statue  Modern Egypt
# 2     35                king_Akhenaten   Statue   New Kingdom
# 3     47            Stela_of_King_Qa'a   Statue   Old Kingdom
# 4     14        Amun_Ra_Kingof_TheGods   Statue   New Kingdom
#
#    Similarity Score
# 0            0.8543
# 1            0.8478
# 2            0.8333
# 3            0.7842
# 4            0.7824

# %%
recommend("Khonsu", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: Khonsu (Index: 5)
#    Index                   Exhibit Category  Time Period  Similarity Score
# 0     42  The_Protective_Goddesses   Statue  New Kingdom            0.8856
# 1     47        Stela_of_King_Qa'a   Statue  Old Kingdom            0.8785
# 2     17     TheCoffinOf_Lady_Isis   Statue  New Kingdom            0.8571
# 3     19     TheCoffinOf_Sennedjem   Statue  New Kingdom            0.8569
# 4     10         King_Thutmose_III   Statue  New Kingdom            0.8560

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nn_model = NearestNeighbors(n_neighbors=6, metric='cosine')  # n_neighbors = top_k + 1 (because first one is itself)
nn_model.fit(combined_features)

# 7. Define Recommend Function
def recommend(exhibit_name, top_k=5, filter_category=None, filter_time_period=None):
    cleaned_exhibit = exhibit_name.strip().lower()

    if cleaned_exhibit not in df['cleaned_exhibit'].values:
        print(f"❌ Exhibit '{exhibit_name}' not found.")
        suggestions = df['exhibits'][df['cleaned_exhibit'].str.contains(cleaned_exhibit[:3])]
        if not suggestions.empty:
            print("🔍 Did you mean:", ", ".join(suggestions.values))
        return pd.DataFrame()

    exhibit_index = df[df['cleaned_exhibit'] == cleaned_exhibit].index[0]
    exhibit_vector = combined_features[exhibit_index].reshape(1, -1)

    distances, indices = nn_model.kneighbors(exhibit_vector)

    recommendations = []
    for idx, dist in zip(indices[0][1:], distances[0][1:]):  # skip self (first neighbor is itself)
        exhibit = df.loc[idx]
        category = exhibit['Category'].strip()
        time_period = exhibit['Time Period'].strip()

        if filter_category and category != filter_category:
            continue
        if filter_time_period and time_period != filter_time_period:
            continue

        recommendations.append({
            "Index": idx,
            "Exhibit": exhibit['exhibits'],
            "Category": category,
            "Time Period": time_period,
            "Similarity Score": round(1 - dist, 4)  # similarity = 1 - distance for cosine
        })

        if len(recommendations) >= top_k:
            break

    recommendations_df = pd.DataFrame(recommendations)
    print(f"\n📍 Top {top_k} Recommendations for: {df.loc[exhibit_index, 'exhibits']} (Index: {exhibit_index})")
    return recommendations_df

# 8. Test it
recommend("Hassan_Fathi", top_k=5)
# Out:
# 📍 Top 5 Recommendations for: Hassan_Fathi (Index: 2)
#    Index                                       Exhibit      Category  \
# 0     27                  Mohamed_Talaat_Pasha_Harb_00        Statue
# 1      0                            the_female_peasent        Statue
# 2     48                          Zaynab_Khatun_house   Architecture
# 3     30  Puplit _of_the_Mosque_of_Abu_Bakr_bin_Mazhar  Architecture
# 4      8                         Box_ofthe_Holy Qur’an      Artifact
#
#     Time Period  Similarity Score
# 0  Modern Egypt            0.8407
# 1  Modern Egypt            0.8216
# 2        Mamluk            0.8184
# 3        Mamluk            0.8064
# 4        Mamluk            0.7959
