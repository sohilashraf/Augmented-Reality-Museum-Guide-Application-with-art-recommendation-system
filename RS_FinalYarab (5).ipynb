# %%
# --- 1. Imports ---
import pandas as pd
import numpy as np
import pickle as pkl
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense, Concatenate, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Accuracy
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf

# --- 2. Load Data ---
ratings_df = pd.read_csv("bbalanced_simulated_ratings_50_users_renamed.csv")
exhibits_df = pd.read_excel("data set - New.xlsx")
with open("all_image_features1.pkl", "rb") as f:
    image_features_dict = pkl.load(f)

# %%
exhibits_df
# Out:
#                                         exhibits  \
# 0                             the_female_peasent
# 1                            Statue_ofthe_sphinx
# 2                                   Hassan_Fathi
# 3                                  Royal_Statues
# 4                                  Greek_Statues
# 5                                         Khonsu
# 6                                    Ra_Horakhty
# 7                                       Senenmut
# 8                          Box_ofthe_Holy Qur’an
# 9                                  The_HolyQuran
# 10                             King_Thutmose_III
# 11                                  King_Fouad_I
# 12                               theVizier_Paser
# 13                Sphinxof_theking_Amenemhat_III
# 14                        Amun_Ra_Kingof_TheGods
# 15                        Nazlet_Khater_Skeleton
# 16               Pen_Menkh_TheGovernerOf_Dendara
# 17                         TheCoffinOf_Lady_Isis
# 18                           CoffinOf_Nedjemankh
# 19                         TheCoffinOf_Sennedjem
# 20                                        A_silo
# 21                           Captives_statuettes
# 22       Chair_from_the tomb_of_Queen_Hetepheres
# 23                                          Maat
# 24                          Mahalawi_water_ewers
# 25                                  Mamluk_Lamps
# 26                                Khedive_Ismail
# 27                  Mohamed_Talaat_Pasha_Harb_00
# 28                             Model_of_building
# 29                            Muhammad_Ali_Pasha
# 30  Puplit _of_the_Mosque_of_Abu_Bakr_bin_Mazhar
# 31                      The_Preist_Psamtik_seneb
# 32      The_Madrasaa_and_Mosque_of_Sultan_Hassan
# 33                             Wekalet_al-Ghouri
# 34                             The_birth_of_Isis
# 35                                king_Akhenaten
# 36              The_Kiswa_Covering_of_holy_Kaaba
# 37              AQueen_in_the_form_of_the_Sphinx
# 38                       Purification_with_water
# 39                                    Mashrabiya
# 40                                     Astrolabe
# 41                                         Baker
# 42                      The_Protective_Goddesses
# 43                                        Miller
# 44                             Hapi_the_Scribe\n
# 45                                         Thoth
# 46                      Ottoman_Period_Carpet \n
# 47                            Stela_of_King_Qa'a
# 48                          Zaynab_Khatun_house
# 49                                     God_Nilus
#
#                                        Text in Arabic  \
# 0   تمثال الفلاحة :يعتبر هذا التمثال من الأعمال ال...
# 1   تمثال لأبي الهول: تمثال مصغر لأبي الهول لا يوج...
# 2   حسن فتحی ( ۱۹۰۰ م- ۱۹۸۹ م ): ولد في الأسكندرية...
# 3   التماثيل المالكية : عند قامت دولة البطالمة في ...
# 4   تماثيل يونانية:كان للفن في اليونان القديمة أثر...
# 5   خونسو: كان خونسو إلها للقمر وأحد أفراد ثالوث م...
# 6   رع حور أختي: كان رع حور أختي يمثل أتحادا عقائد...
# 7   سننموت : عمل سننموت كمستشار مقرب ومعماري للملك...
# 8   صندوق المصحف الشريف : صندوق لحفظ المصحف الشريف...
# 9   المصحف الشريف :                               ...
# 10  الملك تحتمس الثالث :کان تحتمس الثالث من أعظم ا...
# 11  الملك فؤاد الأول ( ١٨٦٨ - ١٩٣٦ ):             ...
# 12  الوزير باسر : عاش " بأسر في عصر الملك " سيتي ا...
# 13  أمنمحات الثالث على هيئة أبي الهول :           ...
# 14  آمون رع ملك الآلهة:                           ...
# 15   انسان نزلة خاطر :                            ...
# 16  بن منخ حاكم دندرة : عاصر بن منخ الملكة كليوبات...
# 17  تابوت السيدة إيزيس :                          ...
# 18  تابوت نجم عنخ :                               ...
# 19  تابوت سن نجم :                                ...
# 20  الصومعة :                                     ...
# 21  تماثيل الأسرى: انت هيئات الأسرى تصنع من خامات ...
# 22  كرسي من مقبرة الملكة حتشبسوت : عود الى الدولة ...
# 23  ماعت : كانت ماعت ابنة إله الشمس أتوم الذي خلقه...
# 24  أباريق الغسيل المحلاوي: مجموعة من الأباريق الم...
# 25  المشكاوات المملوكية: مجموعة من المشكاوات الممل...
# 26  الخديوي إسماعيل (١٨٣٠-١٨٩٥): في عهد الخديوي إس...
# 27  محمد طلعت باشا حرب: (1867-1941) رائد الاقتصاد ...
# 28  نموذج مبنى متعدد الطوابق: يُظهر هذا النموذج مب...
# 29  محمد علي باشا: (1769-1849) ولد في "كافالا" في ...
# 30  منبر مسجد أبو بكر بن مظهر: أبو بكر مظهر كان مس...
# 31  الكاهن بسماتيك سنيب: يعد تمثال حامل الناؤوس أو...
# 32  مدرسة ومسجد السلطان حسن: تعد المدرسة (المدرسة)...
# 33  وكالة الغوري: هي الجزء المتبقي من مجمع السلطان...
# 34  ولادة ايزيس: تم العثور على اللوحة الفريدة بالق...
# 35  الملك إخناتون: عندما تولى أمنحتب الرابع السلطة...
# 36  كسوة الكعبة المشرفة: يعد صنع كسوة الكسوة من أع...
# 37  احدى الملكات على شكل أبو الهول: يعتبر هذا التم...
# 38  التطهير بالماء: عند وصوله من العالم الآخر ، يط...
# 39  المشربية : "تنظيم الضوء فى العمارة الإسلامية" ...
# 40  الإسطرلاب :  هو آلة فلكية يعود إختراعها إلى ال...
# 41  الخبازة: كان الخبز مكوناً أساسياً في غذاء المص...
# 42  الربات الحاميات :\nمجموعة من تماثيل الربات الح...
# 43  الطحان :                                      ...
# 44  الكاتب حعبي : \nكانت الكتبة من بين الأفراد ذوى...
# 45  جحوتى :\nقدس المصريون طائر "أبي منجل” وشبهوا ب...
# 46  سجادة من العصر العثمانى : \nسجادة للإستخدام ال...
# 47  لوحة قا عا :                                  ...
# 48  منزل  زيتب خاتون  :\nيرجع هذا البيت أصلا إلى ش...
# 49  الإله نيلوس :                                 ...
#
#                                       Text in English       Category  \
# 0   The Femal Peasent: This statue is considered o...         Statue
# 1   Statue of the Sphinx: \nStatue of Sphinx, whic...         Statue
# 2   Hassan Fathi (1900-1989):  Hassan Fathi was bo...  Architecture
# 3   Royal Statues: When the Ptolemaic state was es...         Statue
# 4   Greek Statues: The art of ancient Greece had a...         Statue
# 5   Khonsu: Khonsu was the god of the moon and a m...         Statue
# 6   Ra-Horakhty: Ra-Horakhty represented a doctrin...         Statue
# 7   Senenmut : Senenmut served as a close advisor ...         Statue
# 8   Box of the Holy Qur'an: This huge box was made...       Artifact
# 9   The Holy Quran: Finely calligraphed and bound ...       Artifact
# 10  King Thutmose III : Thutmose ill was one of th...         Statue
# 11  King Fouad I ( 1868-1936 ): The son of Khedive...         Statue
# 12  The vizier Paser:  Paser lived during the reig...         Statue
# 13  Sphinxof_theking_Amenemhat_III:  The statues o...         Statue
# 14  Amon-Ra : the king of the gods. Amun-Ra was th...         Statue
# 15  Nazlet Khater Skeleton :  This skeleton was fo...       Artifact
# 16  Pen Menkh TheGovernerOf Dendara : he Greco-Rom...         Statue
# 17  The Coffin of Lady Isis : This coffin was disc...         Statue
# 18  Coffin of Nedjemankh :  Nedjemankh was a pries...         Statue
# 19  The coffin of Sennedjem :  The inner coffin of...         Statue
# 20  A Silo: Silos were used to store grains, mainl...       Artifact
# 21  Captive's statuettes: The figures of captives ...         Statue
# 22  Chair from the tomb of Queen Hetepheres: old k...       Artifact
# 23  Maat: Maat was the daughter of the sun God Atu...         Statue
# 24   "Mahallawi" Water Ewers: A group of "Mahallaw...       Artifact
# 25  Mamluk Lamps : A group of glass lamps decorate...       Artifact
# 26  Khedive Ismail(1830-1895): during the reign of...         Statue
# 27  Mohamed Talaat Pasha Harb: (1867- 1941) A lead...         Statue
# 28  Model of Building: This model shows an apartme...  Architecture
# 29  Muhammad Ali Pasha: (1769 -1849) He was born i...         Statue
# 30  Pulpit of Mosque of Abu Bakr bin Mazhar: Abu B...  Architecture
# 31  The Priest Psamtik Seneb : The Naophorous or N...         Statue
# 32  The Madrasa and Mosque of Sultan Hassan:  The ...  Architecture
# 33  Wekalet al-Ghouri is the remaining part of the...  Architecture
# 34  The birth of isis: The unique plaque was found...         Statue
# 35  king Akhenaten: When Amenhotep IV becomes a ph...         Statue
# 36  The "Kiswa" Covering of the Holy Kaaba: Manufa...       Artifact
# 37  A Queen in the form of the Sphinx: This statue...         Statue
# 38  Purification with water: Upon his arrival from...         Statue
# 39  Mashrabiya "Oriel Window" : \n"The Organizatio...  Architecture
# 40  Astrolabe :   The Astrolabe was invented by th...       Artifact
# 41  Baker :\nBread was an essential part of the di...         Statue
# 42  The Protective Goddesses :     A group of stat...         Statue
# 43  Miller :     It is a unique statue depicting a...         Statue
# 44  Hapi the Scribe :\nScribes were amongst the hi...         Statue
# 45  Thoth :\nThe ancient Egyptians sanctified the ...         Statue
# 46  Ottoman Period Carpet :\nA ground carpet predo...       Artifact
# 47  Stela of King Qa'a :\nQa'a was the lastking of...         Statue
# 48  Zaynab Khatun house :\nThis house originally b...  Architecture
# 49  God Nilus : The god Nilus was a symbol of the ...         Statue
#
#            Time Period  Exhibit_id
# 0         Modern Egypt           1
# 1          Old Kingdom           2
# 2         Modern Egypt           3
# 3            Ptolemaic           4
# 4          Hellenistic           5
# 5          New Kingdom           6
# 6          New Kingdom           7
# 7          New Kingdom           8
# 8               Mamluk           9
# 9         Modern Egypt          10
# 10         New Kingdom          11
# 11        Modern Egypt          12
# 12         New Kingdom          13
# 13      Middle Kingdom          14
# 14         New Kingdom          15
# 15  Ancient Egyptian\t          16
# 16           Ptolemaic          17
# 17         New Kingdom          18
# 18           Ptolemaic          19
# 19         New Kingdom          20
# 20  Ancient Egyptian\t          21
# 21         New Kingdom          22
# 22         Old Kingdom          23
# 23         New Kingdom          24
# 24      Islamic Period          25
# 25              Mamluk          26
# 26        Modern Egypt          27
# 27        Modern Egypt          28
# 28         Greco-Roman          29
# 29        Modern Egypt          30
# 30              Mamluk          31
# 31  Ancient Egyptian\t          32
# 32              Mamluk          33
# 33              Mamluk          34
# 34           Ptolemaic          35
# 35         New Kingdom          36
# 36        Modern Egypt          37
# 37         Old Kingdom          38
# 38         New Kingdom          39
# 39      Islamic Period          40
# 40      Islamic Period          41
# 41         Old Kingdom          42
# 42         New Kingdom          43
# 43         Old Kingdom          44
# 44         New Kingdom          45
# 45         Greco-Roman          46
# 46        Modern Egypt          47
# 47         Old Kingdom          48
# 48              Mamluk          49
# 49         Greco-Roman          50

# %%
ratings_df
# Out:
#      user_id  exhibit_id  rating
# 0     user_1          45       1
# 1     user_1          32       1
# 2     user_1           5       1
# 3     user_1          50       1
# 4     user_1           1       1
# ..       ...         ...     ...
# 995  user_50          33       0
# 996  user_50          22       0
# 997  user_50           4       0
# 998  user_50           5       0
# 999  user_50           8       0
#
# [1000 rows x 3 columns]

# %%
ratings_df = pd.read_csv("bbalanced_simulated_ratings_50_users_renamed.csv")
exhibits_df = pd.read_excel("data set - New.xlsx")
with open("all_image_features1.pkl", "rb") as f:
    image_features_dict = pkl.load(f)

exhibits_df = exhibits_df[['Exhibit_id', 'exhibits', 'Text in English', 'Category', 'Time Period']].dropna()

# ---  Image Features ---
image_features = []
for name in exhibits_df['exhibits']:
    if name in image_features_dict and len(image_features_dict[name]) > 0:
        vectors = [entry['feature'] for entry in image_features_dict[name]]
        avg_vector = np.mean(np.stack(vectors), axis=0)
    else:
        avg_vector = np.zeros(2048)
    image_features.append(avg_vector)
image_features = np.array(image_features)
image_features /= np.linalg.norm(image_features, axis=1, keepdims=True) + 1e-10

# ---  Text + Metadata Features ---
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
texts = exhibits_df['Text in English'].astype(str).tolist()
tokens = tokenizer(texts, padding='max_length', truncation=True, max_length=128, return_tensors="tf")
bert_output = bert_model(input_ids=tokens['input_ids'], attention_mask=tokens['attention_mask'])
text_embeddings = bert_output.last_hidden_state[:, 0, :].numpy()

encoder = OneHotEncoder(sparse_output=False)
category_encoded = encoder.fit_transform(exhibits_df[['Category']])
time_period_encoded = encoder.fit_transform(exhibits_df[['Time Period']])
combined_features = np.concatenate([text_embeddings, category_encoded, time_period_encoded, image_features], axis=1)

# ---  Match Features to Exhibit IDs ---
exhibit_to_vector = dict(zip(exhibits_df['Exhibit_id'], combined_features))
ratings_df['features'] = ratings_df['exhibit_id'].map(exhibit_to_vector)
ratings_df.dropna(subset=['features'], inplace=True)

# ---  Encode Users & Items ---
user_encoder = LabelEncoder()
item_encoder = LabelEncoder()
ratings_df['user_id_encoded'] = user_encoder.fit_transform(ratings_df['user_id'])
ratings_df['item_id_encoded'] = item_encoder.fit_transform(ratings_df['exhibit_id'])

ratings_df['stratify_col'] = ratings_df['user_id_encoded'].astype(str) + "_" + ratings_df['rating'].astype(str)

train_df, test_df = train_test_split(
    ratings_df,
    test_size=0.2,
    random_state=42,
    stratify=ratings_df['stratify_col']
)

train_df.drop(columns=['stratify_col'], inplace=True)
test_df.drop(columns=['stratify_col'], inplace=True)

train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)  # 16% validation



def prepare_inputs(data):
    return [
        np.array(data['user_id_encoded']),
        np.array(data['item_id_encoded']),
        np.stack(data['features'].values)
    ], np.array(data['rating']).astype('float32')

train_inputs, train_labels = prepare_inputs(train_df)
val_inputs, val_labels = prepare_inputs(val_df)
test_inputs, test_labels = prepare_inputs(test_df)




# --- 9. Build the Model (No Dropout) ---
num_users = ratings_df['user_id_encoded'].nunique()
num_items = ratings_df['item_id_encoded'].nunique()
feature_dim = combined_features.shape[1]

user_input = Input(shape=(1,), name='user_input')
item_input = Input(shape=(1,), name='item_input')
features_input = Input(shape=(feature_dim,), name='features_input')

user_embedding = Embedding(input_dim=num_users, output_dim=64)(user_input)
item_embedding = Embedding(input_dim=num_items, output_dim=64)(item_input)
user_vec = Flatten()(user_embedding)
item_vec = Flatten()(item_embedding)

from tensorflow.keras.layers import Dropout  # Make sure this is imported

# Collaborative Filtering Branch
cf_concat = Concatenate()([user_vec, item_vec])
cf_dense = Dense(128, activation='relu')(cf_concat)
cf_dropout = Dropout(0.3)(cf_dense)
cf_out = Dense(64, activation='relu')(cf_dropout)

# Content-Based Branch
cb_dense1 = Dense(256, activation='relu')(features_input)
cb_dropout1 = Dropout(0.3)(cb_dense1)
cb_dense2 = Dense(128, activation='relu')(cb_dropout1)
cb_dropout2 = Dropout(0.3)(cb_dense2)
cb_out = Dense(64, activation='relu')(cb_dropout2)

# Fusion + Deep Feedforward Layers
fusion = Concatenate()([cf_out, cb_out])

fusion_dense1 = Dense(512, activation='relu')(fusion)
fusion_dropout1 = Dropout(0.3)(fusion_dense1)

fusion_dense2 = Dense(256, activation='relu')(fusion_dropout1)
fusion_dropout2 = Dropout(0.3)(fusion_dense2)

fusion_dense3 = Dense(64, activation='relu')(fusion_dropout2)
fusion_dropout3 = Dropout(0.3)(fusion_dense3)

# Final prediction layer
output = Dense(1, activation='sigmoid')(fusion_dropout3)


# Model setup
model = Model(inputs=[user_input, item_input, features_input], outputs=output)
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=[Accuracy(name="accuracy"), AUC(name="auc")])

model.summary()


# --- 10. Train ---
model.fit(train_inputs, train_labels, validation_data=(val_inputs, val_labels), epochs=50, batch_size=32)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ user_input          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ item_input          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_46        │ (None, 1, 64)     │      3,200 │ user_input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_47        │ (None, 1, 64)     │      3,200 │ item_input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ features_input      │ (None, 2829)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_46          │ (None, 64)        │          0 │ embedding_46[0][… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_47          │ (None, 64)        │          0 │ embedding_47[0][… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_167 (Dense)   │ (None, 256)       │    724,480 │ features_input[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_46      │ (None, 128)       │          0 │ flatten_46[0][0], │
# │ (Concatenate)       │                   │            │ flatten_47[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_63          │ (None, 256)       │          0 │ dense_167[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_165 (Dense)   │ (None, 128)       │     16,512 │ concatenate_46[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_168 (Dense)   │ (None, 128)       │     32,896 │ dropout_63[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_62          │ (None, 128)       │          0 │ dense_165[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_64          │ (None, 128)       │          0 │ dense_168[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_166 (Dense)   │ (None, 64)        │      8,256 │ dropout_62[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_169 (Dense)   │ (None, 64)        │      8,256 │ dropout_64[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_47      │ (None, 128)       │          0 │ dense_166[0][0],  │
# │ (Concatenate)       │                   │            │ dense_169[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_170 (Dense)   │ (None, 512)       │     66,048 │ concatenate_47[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_65          │ (None, 512)       │          0 │ dense_170[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_171 (Dense)   │ (None, 256)       │    131,328 │ dropout_65[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_66          │ (None, 256)       │          0 │ dense_171[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_172 (Dense)   │ (None, 64)        │     16,448 │ dropout_66[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_67          │ (None, 64)        │          0 │ dense_172[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_173 (Dense)   │ (None, 1)         │         65 │ dropout_67[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,010,689 (3.86 MB)
#  Trainable params: 1,010,689 (3.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.0000e+00 - auc: 0.4671 - loss: 0.7001 - val_accuracy: 0.0000e+00 - val_auc: 0.6337 - val_loss: 0.6855
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - auc: 0.5245 - loss: 0.6951 - val_accuracy: 0.0000e+00 - val_auc: 0.6839 - val_loss: 0.6794
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.0000e+00 - auc: 0.6457 - loss: 0.6723 - val_accuracy: 0.0000e+00 - val_auc: 0.6886 - val_loss: 0.6481
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - auc: 0.6806 - loss: 0.6497 - val_accuracy: 0.0000e+00 - val_auc: 0.6862 - val_loss: 0.6480
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - auc: 0.6969 - loss: 0.6338 - val_accuracy: 0.0000e+00 - val_auc: 0.6933 - val_loss: 0.6537
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - auc: 0.6996 - loss: 0.6350 - val_accuracy: 0.0000e+00 - val_auc: 0.6626 - val_loss: 0.6482
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - auc: 0.7475 - loss: 0.6028 - val_accuracy: 0.0000e+00 - val_auc: 0.6448 - val_loss: 0.6803
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.0000e+00 - auc: 0.7739 - loss: 0.5703 - val_accuracy: 0.0000e+00 - val_auc: 0.6328 - val_loss: 0.7166
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0000e+00 - auc: 0.8280 - loss: 0.5162 - val_accuracy: 0.0000e+00 - val_auc: 0.6379 - val_loss: 0.7626
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.0000e+00 - auc: 0.8551 - loss: 0.4762 - val_accuracy: 0.0000e+00 - val_auc: 0.6222 - val_loss: 0.7726
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - auc: 0.8965 - loss: 0.4244 - val_accuracy: 0.0000e+00 - val_auc: 0.6453 - val_loss: 0.8851
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - auc: 0.9339 - loss: 0.3348 - val_accuracy: 0.0000e+00 - val_auc: 0.6614 - val_loss: 1.0380
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - auc: 0.9587 - loss: 0.2590 - val_accuracy: 0.0000e+00 - val_auc: 0.6669 - val_loss: 1.2365
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.0021 - auc: 0.9629 - loss: 0.2417 - val_accuracy: 0.0000e+00 - val_auc: 0.6758 - val_loss: 1.2940
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0022 - auc: 0.9713 - loss: 0.2232 - val_accuracy: 0.0000e+00 - val_auc: 0.6794 - val_loss: 1.3533
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0026 - auc: 0.9846 - loss: 0.1654 - val_accuracy: 0.0078 - val_auc: 0.6943 - val_loss: 1.4885
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.0106 - auc: 0.9917 - loss: 0.1231 - val_accuracy: 0.0156 - val_auc: 0.6598 - val_loss: 1.8669
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0149 - auc: 0.9869 - loss: 0.1539 - val_accuracy: 0.0078 - val_auc: 0.6657 - val_loss: 1.8410
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0083 - auc: 0.9936 - loss: 0.1090 - val_accuracy: 0.0078 - val_auc: 0.6495 - val_loss: 1.8121
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0099 - auc: 0.9961 - loss: 0.0863 - val_accuracy: 0.0156 - val_auc: 0.6497 - val_loss: 2.0605
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0143 - auc: 0.9972 - loss: 0.0774 - val_accuracy: 0.0234 - val_auc: 0.6521 - val_loss: 2.1447
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.0228 - auc: 0.9996 - loss: 0.0488 - val_accuracy: 0.0234 - val_auc: 0.6529 - val_loss: 2.4961
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0229 - auc: 0.9903 - loss: 0.0793 - val_accuracy: 0.0312 - val_auc: 0.6519 - val_loss: 2.4807
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0549 - auc: 0.9979 - loss: 0.0591 - val_accuracy: 0.0234 - val_auc: 0.6493 - val_loss: 2.6432
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0355 - auc: 0.9992 - loss: 0.0324 - val_accuracy: 0.0312 - val_auc: 0.6302 - val_loss: 2.7768
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0581 - auc: 0.9996 - loss: 0.0265 - val_accuracy: 0.0312 - val_auc: 0.6226 - val_loss: 2.9654
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.0663 - auc: 0.9980 - loss: 0.0641 - val_accuracy: 0.0312 - val_auc: 0.6299 - val_loss: 2.7709
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0452 - auc: 0.9975 - loss: 0.0705 - val_accuracy: 0.0234 - val_auc: 0.6487 - val_loss: 2.5149
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0500 - auc: 0.9978 - loss: 0.0494 - val_accuracy: 0.0156 - val_auc: 0.6490 - val_loss: 2.3846
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0280 - auc: 0.9991 - loss: 0.0398 - val_accuracy: 0.0156 - val_auc: 0.6437 - val_loss: 2.4465
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0262 - auc: 0.9994 - loss: 0.0264 - val_accuracy: 0.0391 - val_auc: 0.6429 - val_loss: 2.6329
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0372 - auc: 0.9956 - loss: 0.0734 - val_accuracy: 0.0156 - val_auc: 0.6250 - val_loss: 2.5128
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0342 - auc: 0.9993 - loss: 0.0399 - val_accuracy: 0.0312 - val_auc: 0.6309 - val_loss: 2.7205
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0307 - auc: 0.9998 - loss: 0.0164 - val_accuracy: 0.0391 - val_auc: 0.6332 - val_loss: 3.0744
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0743 - auc: 0.9997 - loss: 0.0175 - val_accuracy: 0.0469 - val_auc: 0.6427 - val_loss: 3.3135
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.0827 - auc: 0.9997 - loss: 0.0165 - val_accuracy: 0.0469 - val_auc: 0.6286 - val_loss: 3.3000
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1054 - auc: 0.9999 - loss: 0.0175 - val_accuracy: 0.0391 - val_auc: 0.6315 - val_loss: 3.4100
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.0880 - auc: 0.9988 - loss: 0.0449 - val_accuracy: 0.0781 - val_auc: 0.6487 - val_loss: 3.4001
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.0936 - auc: 0.9989 - loss: 0.0588 - val_accuracy: 0.0234 - val_auc: 0.6386 - val_loss: 2.8578
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0404 - auc: 0.9984 - loss: 0.0525 - val_accuracy: 0.0234 - val_auc: 0.6267 - val_loss: 2.7423
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0366 - auc: 0.9987 - loss: 0.0383 - val_accuracy: 0.0391 - val_auc: 0.6338 - val_loss: 2.8286
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0606 - auc: 0.9997 - loss: 0.0231 - val_accuracy: 0.0391 - val_auc: 0.6389 - val_loss: 3.1552
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.0856 - auc: 1.0000 - loss: 0.0147 - val_accuracy: 0.0391 - val_auc: 0.6090 - val_loss: 3.5072
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0929 - auc: 1.0000 - loss: 0.0101 - val_accuracy: 0.0703 - val_auc: 0.6012 - val_loss: 3.7901
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1290 - auc: 0.9990 - loss: 0.0468 - val_accuracy: 0.0469 - val_auc: 0.6092 - val_loss: 3.4341
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0736 - auc: 0.9998 - loss: 0.0238 - val_accuracy: 0.0391 - val_auc: 0.6289 - val_loss: 3.4239
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0941 - auc: 0.9996 - loss: 0.0361 - val_accuracy: 0.0391 - val_auc: 0.6484 - val_loss: 3.4558
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0730 - auc: 0.9933 - loss: 0.0555 - val_accuracy: 0.0469 - val_auc: 0.6459 - val_loss: 3.2004
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0895 - auc: 0.9999 - loss: 0.0155 - val_accuracy: 0.0547 - val_auc: 0.6498 - val_loss: 3.3554
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.1343 - auc: 1.0000 - loss: 0.0082 - val_accuracy: 0.0703 - val_auc: 0.6372 - val_loss: 3.8080

# %%
# Predict probabilities (between 0 and 1)
y_probs = model.predict(test_inputs)

# Convert probabilities to binary predictions using threshold (e.g., 0.5)
y_preds = (y_probs >= 0.5).astype(int).flatten()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score



# Actual labels
y_true = test_labels

# Calculate each metric
precision = precision_score(y_true, y_preds)
recall = recall_score(y_true, y_preds)
accuracy = accuracy_score(y_true, y_preds)
auc = roc_auc_score(y_true, y_probs)
f1 = 2 * (precision * recall) / (precision + recall + 1e-10)


# Print results
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"Accuracy:  {accuracy:.4f}")
print(f"AUC:       {auc:.4f}")
print(f"F1 Score:  {f1:.4f}")

# %%
model.save("hybrid_recommender_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
